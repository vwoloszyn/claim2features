# %% [markdown]
# ### Util

# %% [markdown]
# #### Hot encode and decode

# %%
import numpy as np
from collections import OrderedDict
from operator import itemgetter


def myHotEncode(input_data, max_vocab=0, vocab2idx=None):
    "Return the hot-vecotor and the vocab2idx."
    if vocab2idx is None:
        vocabFreq = {}
        for i in input_data:
            for j in i:
                if j not in vocabFreq:
                    vocabFreq[j] = 0
                vocabFreq[j] += 1
        vocabFreq = OrderedDict(sorted(vocabFreq.items(), key=itemgetter(1), reverse=True))
        vocab2idx = {}
        count = 0
        for v in vocabFreq:
            count += 1
            if max_vocab > 0 and count > max_vocab:
                break
            vocab2idx[v] = len(vocab2idx)        
    vocabEmbeddings = np.identity(len(vocab2idx), dtype='float32')
    data_ret = []
    for i in input_data:
        i_ = []
        for j in i:
            if j in vocab2idx:
                i_.append(vocabEmbeddings[vocab2idx[j]])
        data_ret.append(sum(i_))
    return data_ret, vocab2idx


def myHotDecode(input_data, vocab2idx):
    "Return the decode as final representation and decode as indexs"
    data_ = []
    data_idx = []
    for i in input_data:
        i_ = []
        i_idx = []
        if len(i) != len(vocab2idx):
            print('Erro:', 'The vocab2idx not fit the input data!')
            return
        for _i, j in enumerate(i):
            if j > 0:
                v = [k for k in vocab2idx if vocab2idx[k]==_i][0]
                i_.append(v)
                i_idx.append(_i)
        data_.append(i_)
        data_idx.append(i_idx)
    return data_, data_idx

# %%
import pandas as pd


data_path = 'features_annotated.csv'
df = pd.read_csv(data_path)

# %%
import ast


columns = ['attrs', 'label', 'level', 'tag', 'text', 'url']

last_url = ''
batches = []

css_tss = []
id_tss = []
level_tss = []
tag_tss = []
css_ts = []
id_ts = []
level_ts = []
tag_ts = []

labels = []
labels_batch = []
label = 'None'

last_level = -1

for attr, label_, level, tag, text, url in df[columns].values:
    attr = ast.literal_eval(attr)
    if url != last_url:
        css_tss.append(css_ts.copy())
        id_tss.append(id_ts.copy())
        level_tss.append(level_ts.copy())
        tag_tss.append(tag_ts.copy())
        css_ts = []
        id_ts = []
        level_ts = []
        tag_ts = []
        labels_batch.append(label)
        aux_list = []
        aux_list.append(css_tss.copy())
        aux_list.append(id_tss.copy())
        aux_list.append(level_tss.copy())
        aux_list.append(tag_tss.copy())
        batches.append(aux_list)
        css_tss = []
        id_tss = []
        level_tss = []
        tag_tss = []
        labels.append(labels_batch.copy())
        labels_batch = []
        last_url = url
        label = 'None'
    if label_ != 'None':
        label = label_
    if level > last_level:
        if 'class' in attr:
            css_ts.append(attr['class'])
        else:
            css_ts.append([])
        aux_list = []
        if 'id' in attr:
            aux_list.append(attr['id'])
        if 'name' in attr:
            aux_list.append(attr['name'])
        id_ts.append(aux_list)
        tag_ts.append(tag)
        level_ts.append(level)
    else:
        css_tss.append(css_ts.copy())
        id_tss.append(id_ts.copy())
        level_tss.append(level_ts.copy())
        tag_tss.append(tag_ts.copy())
        css_ts = css_ts[:level]
        id_ts = id_ts[:level]
        level_ts = level_ts[:level]
        tag_ts = tag_ts[:level]
        labels_batch.append(label)
    last_level = level

css_tss.append(css_ts.copy())
id_tss.append(id_ts.copy())
level_tss.append(level_ts.copy())
tag_tss.append(tag_ts.copy())
labels_batch.append(label)
aux_list = []
aux_list.append(css_tss.copy())
aux_list.append(id_tss.copy())
aux_list.append(level_tss.copy())
aux_list.append(tag_tss.copy())
batches.append(aux_list)
labels.append(labels_batch.copy())
batches = batches[1:]

# %%
batches[0][3]
# Out:
# [['[document]', 'html', 'head', 'meta'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'head'],
#  ['[document]', 'html', 'noscript', 'iframe'],
#  ['[document]', 'html', 'noscript'],
#  ['[document]', 'html', 'noscript', 'div', 'span'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'div', 'a', 'i'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'div', 'a', 'img'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'div', 'a', 'img'],
#  ['[document]',
#   'html',
#   'noscript',
#   'div',
#   'div',
#   'div',
#   'a',
#   'form',
#   'div',
#   'div',
#   'input'],
#  ['[document]',
#   'html',
#   'noscript',
#   'div',
#   'div',
#   'div',
#   'a',
#   'form',
#   'div',
#   'i'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'div', 'a', 'form', 'i'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'div', 'ul', 'li', 'a', 'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'div',
#   'div',
#   'div',
#   'ul',
#   'li',
#   'a',
#   'form',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'div',
#   'div',
#   'div',
#   'ul',
#   'li',
#   'a',
#   'form',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'div',
#   'div',
#   'div',
#   'ul',
#   'li',
#   'a',
#   'form',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'div',
#   'div',
#   'div',
#   'ul',
#   'li',
#   'a',
#   'form',
#   'i'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'span'],
#  ['[document]', 'html', 'noscript', 'div', 'span', 'span'],
#  ['[document]', 'html', 'noscript', 'div', 'span'],
#  ['[document]', 'html', 'noscript', 'section', 'div', 'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'span'],
#  ['[document]', 'html', 'noscript', 'section', 'div', 'span', 'div', 'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'i',
#   'li',
#   'a'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'i',
#   'li',
#   'a'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'h1'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'h1'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'img'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'img'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'a'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'span',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'a',
#   'img'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'a',
#   'img'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'a'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'a'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'p'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'p',
#   'a'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'div',
#   'span',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'a'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'em'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'em'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'h3',
#   'p'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'a'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'p'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'p',
#   'a'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'span',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'div',
#   'a'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'div',
#   'a'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'div',
#   'span',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'p',
#   'br'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'p',
#   'br'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'p',
#   'br'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'p',
#   'br'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'p',
#   'br'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'p',
#   'br'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'p',
#   'br'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'p',
#   'br'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'h3'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'header',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'div',
#   'span',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'div',
#   'span'],
#  ['[document]', 'html', 'noscript', 'section', 'div', 'span', 'div', 'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'a',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'a'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'div',
#   'span',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'div',
#   'span'],
#  ['[document]', 'html', 'noscript', 'section', 'div', 'span', 'div', 'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'a',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'a'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article',
#   'a',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'article'],
#  ['[document]', 'html', 'noscript', 'section', 'div', 'span', 'div', 'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'div',
#   'span',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'div',
#   'span'],
#  ['[document]',
#   'html',
#   'noscript',
#   'section',
#   'div',
#   'span',
#   'div',
#   'div',
#   'span'],
#  ['[document]', 'html', 'noscript', 'section', 'div', 'span'],
#  ['[document]', 'html', 'noscript', 'div', 'span'],
#  ['[document]', 'html', 'noscript', 'div', 'span', 'span'],
#  ['[document]', 'html', 'noscript', 'div', 'span'],
#  ['[document]', 'html', 'noscript', 'div', 'nav', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'nav', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'nav', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'nav', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'nav', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'nav', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'nav', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'nav', 'div', 'ul', 'li', 'a'],
#  ['[document]', 'html', 'noscript', 'div', 'nav', 'div', 'ul', 'li', 'a'],
#  ['[document]',
#   'html',
#   'noscript',
#   'div',
#   'div',
#   'div',
#   'div',
#   'h2',
#   'a',
#   'img'],
#  ['[document]',
#   'html',
#   'noscript',
#   'div',
#   'div',
#   'div',
#   'div',
#   'div',
#   'a',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'div',
#   'div',
#   'div',
#   'div',
#   'div',
#   'a',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'div',
#   'div',
#   'div',
#   'div',
#   'div',
#   'a',
#   'i'],
#  ['[document]',
#   'html',
#   'noscript',
#   'div',
#   'div',
#   'div',
#   'div',
#   'div',
#   'a',
#   'i'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'div', 'div', 'p', 'span'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'div', 'div', 'p', 'span'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'div', 'div', 'p', 'span'],
#  ['[document]', 'html', 'noscript', 'form', 'div', 'div', 'label'],
#  ['[document]', 'html', 'noscript', 'form', 'div', 'div', 'label'],
#  ['[document]', 'html', 'noscript', 'form', 'div', 'div', 'label'],
#  ['[document]', 'html', 'noscript', 'form', 'div', 'div', 'label'],
#  ['[document]', 'html', 'noscript', 'form', 'div', 'div', 'div', 'input'],
#  ['[document]', 'html', 'noscript', 'form', 'div', 'div', 'div', 'input', 'a'],
#  ['[document]', 'html', 'noscript', 'form', 'div', 'div', 'div', 'input', 'a'],
#  ['[document]', 'html', 'noscript', 'form', 'div', 'div', 'div'],
#  ['[document]', 'html', 'noscript', 'form', 'div', 'div', 'div'],
#  ['[document]', 'html', 'noscript', 'form', 'div'],
#  ['[document]', 'html', 'noscript', 'form', 'div'],
#  ['[document]', 'html', 'noscript', 'form', 'div'],
#  ['[document]', 'html', 'noscript', 'form', 'div'],
#  ['[document]', 'html', 'noscript', 'form', 'div'],
#  ['[document]',
#   'html',
#   'noscript',
#   'div',
#   'div',
#   'div',
#   'div',
#   'button',
#   'span'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'div', 'div', 'button'],
#  ['[document]', 'html', 'noscript', 'div', 'div', 'div', 'div'],
#  ['[document]', 'html', 'noscript']]
